# %%
pip install torch transformers

# %%
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel

model_name = 'gpt2'  # You can also use 'gpt2-medium', 'gpt2-large', 'gpt2-xl'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

model.eval()

def generate_text(prompt, max_length=200):
    input_ids = tokenizer.encode(prompt, return_tensors='pt')

    with torch.no_grad():
        output = model.generate(
            input_ids,
            max_length=max_length,
            num_return_sequences=1,
            no_repeat_ngram_size=2,
            top_k=50,
            top_p=0.95,
            temperature=0.7
        )

    generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
    return generated_text
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
prompt_examples = [
    "What is a balance sheet",
    "What is the Federal Reserve",
    "What are Investment strategies",
    "What are Credit ratings"
]

for prompt in prompt_examples:
    generated = generate_text(prompt)
    print(f"Prompt: '{prompt}' -> Answer: '{generated}'")
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:628: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:633: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.95` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Prompt: 'What is a balance sheet' -> Answer: 'What is a balance sheet?
#
# A balance account is an account that is used to pay for a certain amount of money. It is not a bank account.
# . A balance is the amount that you pay to the bank for the account you have. The balance you are paying is called a "balance sheet".
#  (See also: Balance sheet)
# , and
# : A bank balance. (see also : Balance Sheet) A financial institution is one that has a financial system that allows it to make money from the sale of assets. This means that it can make a profit from selling assets, but it cannot make any profit on the purchase of the assets that are sold. For example, a company that makes money by selling its stock may not be able to sell its shares of stock because it is unable to do so. In this case, the company may be unable, because of its financial condition, to buy the shares. However, if the stock is sold, it may still'
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Prompt: 'What is the Federal Reserve' -> Answer: 'What is the Federal Reserve's role in the economy?
#
# The Federal Open Market Committee (FOMC) is a federal agency that oversees the Fed's monetary policy. The FOMS is responsible for overseeing the monetary policies of the U.S. Federal Deposit Insurance Corporation (FDIC), the National Credit Union Administration (NCUA), and the Securities and Exchange Commission (SEC).
# .
#  (1) The Federal reserve system is an independent agency of central banks. (2) It is composed of a central bank, the Treasury, and a private sector. It has the power to issue and issue money. In addition, it has a reserve fund, which is used to pay interest on the money it issues. This reserve is called the "money supply."
# , a government-owned bank. Its principal purpose is to provide liquidity to the banking system. However, its main function is not to lend money to banks, but to buy and sell securities. As a result, banks'
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Prompt: 'What are Investment strategies' -> Answer: 'What are Investment strategies for investors?
#
# Investment strategies are a way to make money. They are not a substitute for investing in stocks or bonds.
# . Investment strategy is a means to an end. It is not an investment strategy. The investment is the result of a process of action. A process is an action that is taken by a person or group of people. In other words, it is something that happens in the world. There are many different investment strategies. Some are more effective than others. Others are less effective. But there are some that are better than some. So, if you want to invest in a stock or bond, you need to know what investment you are investing. You need a good understanding of the process. And you also need an understanding that you can make a profit. That is what you should do. If you don't know how to do that, then you will not be able to get a great investment.'
# Prompt: 'What are Credit ratings' -> Answer: 'What are Credit ratings?
#
# Credit ratings are a measure of how well a company is performing in a given market. They are used to determine whether a business is profitable or not.
# . Credit rating is a measurement of the company's performance in that market, and is used by many companies to measure their performance. The most common credit rating used is the FICO. A credit score is calculated by dividing the number of credit hours a customer spends by the average number that a credit card issuer has. For example, if a consumer spends $100 on a card, the credit ratings for that card are $1.50. If a person spends more than $200 on an account, they are considered to be "credit-worthy."
#  (Credit rating) is an indicator of a firm's ability to meet its customers' needs. It is based on the amount of money a user spends on purchases, which is determined by how much money they spend on goods and services. (credit rating ='
