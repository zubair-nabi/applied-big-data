# %%
import pandas as pd
import numpy as np

np.random.seed(42)

accounts = ['ACC123456', 'ACC234567', 'ACC345678', 'ACC456789', 'ACC567890']
merchants = ['ABC Store', 'ATM', 'Employer', 'Stock Exchange', 'XYZ Electronics', 'Online Store', 'Cafe', 'Supermarket']

n_rows = 10000

data = {
    'Transaction ID': np.arange(1000000000, 1000000000 + n_rows),
    'Account ID': np.random.choice(accounts, n_rows),
    'Transaction Amount': np.round(np.random.uniform(10.00, 2000.00, n_rows), 2),
    'Transaction Type': np.random.choice(['Purchase', 'Withdrawal', 'Deposit', 'Trade'], n_rows),
    'Merchant/Counterparty': np.random.choice(merchants, n_rows),
    'Location': np.random.choice(['New York, NY', 'Los Angeles, CA', 'Chicago, IL', 'Miami, FL', 'Online'], n_rows),
    'Date and Time': pd.date_range(start='2024-08-01', periods=n_rows, freq='H').strftime('%Y-%m-%d %H:%M').tolist()
}

pdf = pd.DataFrame(data)
# Out:
# <ipython-input-1-8e5391fd6fea>:18: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   'Date and Time': pd.date_range(start='2024-08-01', periods=n_rows, freq='H').strftime('%Y-%m-%d %H:%M').tolist()

# %%
pip install ctgan

# %%
from ctgan import CTGAN

pdf['Date and Time'] = pd.to_datetime(pdf['Date and Time'], format='%Y-%m-%d %H:%M')

pdf['timestamp'] = pdf['Date and Time'].astype(np.int64) // 10**9

pdf = pdf.drop(['Date and Time'], axis=1)

discrete_columns = [
    'Account ID',
    'Transaction Type',
    'Merchant/Counterparty',
    'Location'
]

ctgan = CTGAN(epochs=50, batch_size=500)
ctgan.fit(pdf, discrete_columns)

synthetic_pdf = ctgan.sample(len(pdf))

synthetic_pdf.head()
# Out:
#    Transaction ID Account ID  Transaction Amount Transaction Type  \
# 0      1000000487  ACC234567         1650.795839       Withdrawal
# 1      1000001515  ACC456789         1236.330512       Withdrawal
# 2      1000006962  ACC456789         1065.559760          Deposit
# 3      1000000531  ACC234567          529.853641          Deposit
# 4      1000004373  ACC456789         1834.726877       Withdrawal
#
#   Merchant/Counterparty         Location   timestamp
# 0             ABC Store  Los Angeles, CA  1734825942
# 1                  Cafe  Los Angeles, CA  1720312119
# 2                  Cafe      Chicago, IL  1721490694
# 3        Stock Exchange        Miami, FL  1728236832
# 4        Stock Exchange           Online  1737689282
