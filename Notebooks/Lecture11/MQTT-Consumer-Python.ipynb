# %% [markdown]
# This notebook will subscribe to the lecture11 topic on the same MQTT broker (`broker.hivemq.com`) and print any received messages. Whenever a new message is published to the topic (e.g., by the Publisher Notebook), it will be printed in real-time as it arrives

# %%
pip install paho-mqtt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.9 MB/s eta 0:00:00
# ...

# %%
import paho.mqtt.client as mqtt
import json

broker = "broker.hivemq.com"
port = 1883
topic = "lecture11"

def on_message(client, userdata, msg):
    message = json.loads(msg.payload.decode('utf-8'))
    print(f"Message received: {message}")

client = mqtt.Client()
client.on_message = on_message

client.connect(broker, port, 60)
client.subscribe(topic)

client.loop_forever()
# Out:
# <ipython-input-2-12ff522faef9>:12: DeprecationWarning: Callback API version 1 is deprecated, update to latest version
#   client = mqtt.Client()
# Message received: {'sensorId': 'temp-sensor-001', 'value': 70.24, 'quality': 'Good', 'timestamp': '2025-04-10T22:47:07Z'}
# Message received: {'sensorId': 'temp-sensor-001', 'value': 71.05, 'quality': 'Good', 'timestamp': '2025-04-10T22:47:08Z'}
# Message received: {'sensorId': 'temp-sensor-001', 'value': 98.85, 'quality': 'Good', 'timestamp': '2025-04-10T22:47:09Z'}
# Message received: {'sensorId': 'temp-sensor-001', 'value': 65.5, 'quality': 'Fair', 'timestamp': '2025-04-10T22:47:10Z'}
# Message received: {'sensorId': 'temp-sensor-001', 'value': 60.28, 'quality': 'Fair', 'timestamp': '2025-04-10T22:47:11Z'}
# Message received: {'sensorId': 'temp-sensor-001', 'value': 70.08, 'quality': 'Good', 'timestamp': '2025-04-10T22:47:12Z'}
# ...
