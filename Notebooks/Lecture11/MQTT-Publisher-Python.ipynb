# %% [markdown]
# This notebook will continuously publish a JSON message to the lecture11 topic on the public MQTT broker (`broker.hivemq.com`).  The message will contain sensor data such as sensorId, value, quality, and timestamp. The message will be published once every second

# %%
pip install paho-mqtt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.9 MB/s eta 0:00:00
# ...

# %%
import paho.mqtt.client as mqtt
import json
import random
from datetime import datetime
import time

broker = "broker.hivemq.com"
port = 1883
topic = "lecture11"

client = mqtt.Client()

client.connect(broker, port, 60)

def publish_message():
    random_value = round(random.uniform(60.0, 100.0), 2)
    quality = "Good" if random_value > 70 else "Fair"

    message = {
        "sensorId": "temp-sensor-001",
        "value": random_value,
        "quality": quality,
        "timestamp": datetime.now().strftime('%Y-%m-%dT%H:%M:%SZ')
    }

    message_str = json.dumps(message)

    client.publish(topic, message_str, retain=False)
    print(f"Message published: {message_str}")

try:
    while True:
        publish_message()
        time.sleep(1)
except KeyboardInterrupt:
    print("Publisher stopped.")
    client.disconnect()
# Out:
# <ipython-input-2-c575a59a48a9>:11: DeprecationWarning: Callback API version 1 is deprecated, update to latest version
#   client = mqtt.Client()
# Message published: {"sensorId": "temp-sensor-001", "value": 70.24, "quality": "Good", "timestamp": "2025-04-10T22:47:07Z"}
# Message published: {"sensorId": "temp-sensor-001", "value": 71.05, "quality": "Good", "timestamp": "2025-04-10T22:47:08Z"}
# Message published: {"sensorId": "temp-sensor-001", "value": 98.85, "quality": "Good", "timestamp": "2025-04-10T22:47:09Z"}
# Message published: {"sensorId": "temp-sensor-001", "value": 65.5, "quality": "Fair", "timestamp": "2025-04-10T22:47:10Z"}
# Message published: {"sensorId": "temp-sensor-001", "value": 60.28, "quality": "Fair", "timestamp": "2025-04-10T22:47:11Z"}
# Message published: {"sensorId": "temp-sensor-001", "value": 70.08, "quality": "Good", "timestamp": "2025-04-10T22:47:12Z"}
# ...
