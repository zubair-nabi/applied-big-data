# %%
pip install fastparquet
# Out:
# Collecting fastparquet
#   Downloading fastparquet-2024.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from fastparquet) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fastparquet) (1.26.4)
# Collecting cramjam>=2.3 (from fastparquet)
#   Downloading cramjam-2.9.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from fastparquet) (2024.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from fastparquet) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->fastparquet) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->fastparquet) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Downloading fastparquet-2024.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 25.0 MB/s eta 0:00:00
# Downloading cramjam-2.9.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 56.5 MB/s eta 0:00:00
# Installing collected packages: cramjam, fastparquet
# Successfully installed cramjam-2.9.1 fastparquet-2024.11.0

# %%
import pandas as pd
import numpy as np

np.random.seed(42)

accounts = ['ACC123456', 'ACC234567', 'ACC345678', 'ACC456789', 'ACC567890']
merchants = ['ABC Store', 'ATM', 'Employer', 'Stock Exchange', 'XYZ Electronics', 'Online Store', 'Cafe', 'Supermarket']

n_rows = 10000

data = {
    'Transaction ID': np.arange(1000000000, 1000000000 + n_rows),
    'Account ID': np.random.choice(accounts, n_rows),
    'Transaction Amount': np.round(np.random.uniform(10.00, 2000.00, n_rows), 2),
    'Transaction Type': np.random.choice(['Purchase', 'Withdrawal', 'Deposit', 'Trade'], n_rows),
    'Merchant/Counterparty': np.random.choice(merchants, n_rows),
    'Location': np.random.choice(['New York, NY', 'Los Angeles, CA', 'Chicago, IL', 'Miami, FL', 'Online'], n_rows),
    'Date and Time': pd.date_range(start='2024-08-01', periods=n_rows, freq='H').strftime('%Y-%m-%d %H:%M').tolist()
}

data = pd.DataFrame(data)

parquet_file = "financial.parquet"
data.to_parquet(parquet_file, engine='fastparquet', index=False)
data
# Out:
# <ipython-input-34-6dae292a6886>:18: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   'Date and Time': pd.date_range(start='2024-08-01', periods=n_rows, freq='H').strftime('%Y-%m-%d %H:%M').tolist()
#       Transaction ID Account ID  Transaction Amount Transaction Type  \
# 0         1000000000  ACC456789               86.80          Deposit
# 1         1000000001  ACC567890             1758.97       Withdrawal
# 2         1000000002  ACC345678              636.72         Purchase
# 3         1000000003  ACC567890              266.67          Deposit
# 4         1000000004  ACC567890              942.24          Deposit
# ...              ...        ...                 ...              ...
# 9995      1000009995  ACC234567             1770.98          Deposit
# 9996      1000009996  ACC345678             1512.92         Purchase
# 9997      1000009997  ACC234567              653.26            Trade
# 9998      1000009998  ACC456789             1876.98       Withdrawal
# 9999      1000009999  ACC345678              162.44          Deposit
#
#      Merchant/Counterparty         Location     Date and Time
# 0                 Employer  Los Angeles, CA  2024-08-01 00:00
# 1                ABC Store      Chicago, IL  2024-08-01 01:00
# 2          XYZ Electronics     New York, NY  2024-08-01 02:00
# 3                 Employer     New York, NY  2024-08-01 03:00
# 4                      ATM      Chicago, IL  2024-08-01 04:00
# ...                    ...              ...               ...
# 9995             ABC Store        Miami, FL  2025-09-21 11:00
# 9996           Supermarket     New York, NY  2025-09-21 12:00
# 9997              Employer  Los Angeles, CA  2025-09-21 13:00
# 9998          Online Store           Online  2025-09-21 14:00
# 9999           Supermarket      Chicago, IL  2025-09-21 15:00
#
# [10000 rows x 7 columns]

# %%
from fastparquet import ParquetFile

pf = ParquetFile(parquet_file)

# Display schema
print("\nParquet Schema:")
print(pf.schema)
# Out:
# Parquet Schema:
# - schema:
# | - Transaction ID: INT64, OPTIONAL
# | - Account ID: BYTE_ARRAY, UTF8, OPTIONAL
# | - Transaction Amount: DOUBLE, OPTIONAL
# | - Transaction Type: BYTE_ARRAY, UTF8, OPTIONAL
# | - Merchant/Counterparty: BYTE_ARRAY, UTF8, OPTIONAL
# | - Location: BYTE_ARRAY, UTF8, OPTIONAL
#   - Date and Time: BYTE_ARRAY, UTF8, OPTIONAL

# %%
# Display row group information
print("\nRow Groups Information:")
print(f"Number of row groups: {len(pf.row_groups)}")
for i, rg in enumerate(pf.row_groups):
    print(f"Row group {i + 1}: {rg.num_rows} rows")
# Out:
# Row Groups Information:
# Number of row groups: 1
# Row group 1: 10000 rows

# %%
# Display column-level statistics
print("\nColumn Statistics:")
print(f"Min={pf.statistics['min']}")
print(f"Max={pf.statistics['max']}")
print(f"Nulls={pf.statistics['null_count']}")
# Out:
# Column Statistics:
# Min={'Transaction ID': [1000000000], 'Account ID': [None], 'Transaction Amount': [10.11], 'Transaction Type': [None], 'Merchant/Counterparty': [None], 'Location': [None], 'Date and Time': [None]}
# Max={'Transaction ID': [1000009999], 'Account ID': [None], 'Transaction Amount': [1999.85], 'Transaction Type': [None], 'Merchant/Counterparty': [None], 'Location': [None], 'Date and Time': [None]}
# Nulls={'Transaction ID': [0], 'Account ID': [0], 'Transaction Amount': [0], 'Transaction Type': [0], 'Merchant/Counterparty': [0], 'Location': [0], 'Date and Time': [0]}

# %%
# Display compression and encoding details
print("\nCompression and Encoding Details:")
for rg in pf.row_groups:
    for col_meta in rg.columns:
        column_name = col_meta.meta_data.path_in_schema[0]
        print(column_name, col_meta)
# Out:
# Compression and Encoding Details:
# Transaction ID column_index_length: null
# column_index_offset: null
# crypto_metadata: null
# encrypted_column_metadata: null
# file_offset: 4
# file_path: null
# meta_data:
#   bloom_filter_offset: null
#   codec: 1
#   data_page_offset: 4
#   dictionary_page_offset: null
#   encoding_stats:
#   - count: 1
#     encoding: 0
#     page_type: 0
#   encodings:
#   - 0
#   index_page_offset: null
#   key_value_metadata: []
#   num_values: 10000
#   path_in_schema:
#   - Transaction ID
#   statistics:
#     distinct_count: null
#     max: b'\x0f\xf1\x9a;\x00\x00\x00\x00'
#     max_value: null
#     min: b'\x00\xca\x9a;\x00\x00\x00\x00'
#     min_value: null
#     null_count: 0
#   total_compressed_size: 40069
#   total_uncompressed_size: 80039
#   type: 2
# offset_index_length: null
# offset_index_offset: null
#
# Account ID column_index_length: null
# column_index_offset: null
# crypto_metadata: null
# encrypted_column_metadata: null
# file_offset: 40073
# file_path: null
# meta_data:
#   bloom_filter_offset: null
#   codec: 1
#   data_page_offset: 40073
#   dictionary_page_offset: null
#   encoding_stats:
#   - count: 1
#     encoding: 0
#     page_type: 0
#   encodings:
#   - 0
#   index_page_offset: null
#   key_value_metadata: []
#   num_values: 10000
#   path_in_schema:
#   - Account ID
#   statistics:
#     distinct_count: null
#     max: null
#     max_value: null
#     min: null
#     min_value: null
#     null_count: 0
#   total_compressed_size: 24129
#   total_uncompressed_size: 130039
#   type: 6
# offset_index_length: null
# offset_index_offset: null
#
# Transaction Amount column_index_length: null
# column_index_offset: null
# crypto_metadata: null
# encrypted_column_metadata: null
# file_offset: 64202
# file_path: null
# meta_data:
#   bloom_filter_offset: null
#   codec: 1
#   data_page_offset: 64202
#   dictionary_page_offset: null
#   encoding_stats:
#   - count: 1
#     encoding: 0
#     page_type: 0
#   encodings:
#   - 0
#   index_page_offset: null
#   key_value_metadata: []
#   num_values: 10000
#   path_in_schema:
#   - Transaction Amount
#   statistics:
#     distinct_count: null
#     max: b'fffff?\x9f@'
#     max_value: null
#     min: b'\xb8\x1e\x85\xebQ8$@'
#     min_value: null
#     null_count: 0
#   total_compressed_size: 48356
#   total_uncompressed_size: 80039
#   type: 5
# offset_index_length: null
# offset_index_offset: null
#
# Transaction Type column_index_length: null
# column_index_offset: null
# crypto_metadata: null
# encrypted_column_metadata: null
# file_offset: 112558
# file_path: null
# meta_data:
#   bloom_filter_offset: null
#   codec: 1
#   data_page_offset: 112558
#   dictionary_page_offset: null
#   encoding_stats:
#   - count: 1
#     encoding: 0
#     page_type: 0
#   encodings:
#   - 0
#   index_page_offset: null
#   key_value_metadata: []
#   num_values: 10000
#   path_in_schema:
#   - Transaction Type
#   statistics:
#     distinct_count: null
#     max: null
#     max_value: null
#     min: null
#     min_value: null
#     null_count: 0
#   total_compressed_size: 19913
#   total_uncompressed_size: 114637
#   type: 6
# offset_index_length: null
# offset_index_offset: null
#
# Merchant/Counterparty column_index_length: null
# column_index_offset: null
# crypto_metadata: null
# encrypted_column_metadata: null
# file_offset: 132471
# file_path: null
# meta_data:
#   bloom_filter_offset: null
#   codec: 1
#   data_page_offset: 132471
#   dictionary_page_offset: null
#   encoding_stats:
#   - count: 1
#     encoding: 0
#     page_type: 0
#   encodings:
#   - 0
#   index_page_offset: null
#   key_value_metadata: []
#   num_values: 10000
#   path_in_schema:
#   - Merchant/Counterparty
#   statistics:
#     distinct_count: null
#     max: null
#     max_value: null
#     min: null
#     min_value: null
#     null_count: 0
#   total_compressed_size: 24633
#   total_uncompressed_size: 135012
#   type: 6
# offset_index_length: null
# offset_index_offset: null
#
# Location column_index_length: null
# column_index_offset: null
# crypto_metadata: null
# encrypted_column_metadata: null
# file_offset: 157104
# file_path: null
# meta_data:
#   bloom_filter_offset: null
#   codec: 1
#   data_page_offset: 157104
#   dictionary_page_offset: null
#   encoding_stats:
#   - count: 1
#     encoding: 0
#     page_type: 0
#   encodings:
#   - 0
#   index_page_offset: null
#   key_value_metadata: []
#   num_values: 10000
#   path_in_schema:
#   - Location
#   statistics:
#     distinct_count: null
#     max: null
#     max_value: null
#     min: null
#     min_value: null
#     null_count: 0
#   total_compressed_size: 22950
#   total_uncompressed_size: 146568
#   type: 6
# offset_index_length: null
# offset_index_offset: null
#
# Date and Time column_index_length: null
# column_index_offset: null
# crypto_metadata: null
# encrypted_column_metadata: null
# file_offset: 180054
# file_path: null
# meta_data:
#   bloom_filter_offset: null
#   codec: 1
#   data_page_offset: 180054
#   dictionary_page_offset: null
#   encoding_stats:
#   - count: 1
#     encoding: 0
#     page_type: 0
#   encodings:
#   - 0
#   index_page_offset: null
#   key_value_metadata: []
#   num_values: 10000
#   path_in_schema:
#   - Date and Time
#   statistics:
#     distinct_count: null
#     max: null
#     max_value: null
#     min: null
#     min_value: null
#     null_count: 0
#   total_compressed_size: 42096
#   total_uncompressed_size: 200039
#   type: 6
# offset_index_length: null
# offset_index_offset: null

# %%
# Demonstrate file size advantage
import os
csv_file = "example.csv"
data.to_csv(csv_file, index=False)
csv_size = os.path.getsize(csv_file)
parquet_size = os.path.getsize(parquet_file)
print(f"\nFile Size Comparison:\nCSV Size: {csv_size / 1024:.2f} KB\nParquet Size: {parquet_size / 1024:.2f} KB")
# Out:
# File Size Comparison:
# CSV Size: 757.73 KB
# Parquet Size: 218.82 KB

# %%
# Display Parquet footer
print("\nParquet Footer:")
print(pf.fmd)
# Out:
# Parquet Footer:
# column_orders: null
# created_by: b'fastparquet-python version 2024.11.0 (build 0)'
# encryption_algorithm: null
# footer_signing_key_metadata: null
# key_value_metadata:
# - key: b'pandas'
#   value: 'b''{"column_indexes": [{"field_name": null, "metadata": null, "name": null,
#     "numpy_type": "object", "pandas_type": "mixed-integer"}], "columns": [{"field_name":
#     "Transaction ID", "metadata": null, "name": "Transaction ID", "numpy_type": "int64",
#     "pandas_type": "int64"}, {"field_name": "Account ID", "metadata": null, "name":
#     "Account ID", "numpy_type": "object", "pandas_type": "unicode"}, {"field_name":
#     "Transaction Amount", "metadata": null, "name": "Transaction Amount", "numpy_type":
#     "float64", "pandas_type": "float64"}, {"field_name": "Transaction Type", "metadata":
#     null, "name": "Transaction Type", "numpy_type": "object", "pandas_type": "unicode"},
#     {"field_name": "Merchant/Counterparty", "metadata": null, "name": "Merchant/Counterparty",
#     "numpy_type": "object", "pandas_type": "unicode"}, {"field_name": "Location",
#     "metadata": null, "name": "Location", "numpy_type": "object", "pandas_type": "unicode"},
#     {"field_name": "Date and Time", "metadata": null, "name": "Date and Time", "numpy_type":
#     "object", "pandas_type": "unicode"}], "creator": {"library": "fastparquet", "version":
#     "2024.11.0"}, "index_columns": [], "pandas_version": "2.2.2", "partition_columns":
#     []}'''
# num_rows: 10000
# row_groups:
# - columns:
#   - column_index_length: null
#     column_index_offset: null
#     crypto_metadata: null
#     encrypted_column_metadata: null
#     file_offset: 4
#     file_path: null
#     meta_data:
#       bloom_filter_offset: null
#       codec: 1
#       data_page_offset: 4
#       dictionary_page_offset: null
#       encoding_stats:
#       - count: 1
#         encoding: 0
#         page_type: 0
#       encodings:
#       - 0
#       index_page_offset: null
#       key_value_metadata: []
#       num_values: 10000
#       path_in_schema:
#       - Transaction ID
#       statistics:
#         distinct_count: null
#         max: b'\x0f\xf1\x9a;\x00\x00\x00\x00'
#         max_value: null
#         min: b'\x00\xca\x9a;\x00\x00\x00\x00'
#         min_value: null
#         null_count: 0
#       total_compressed_size: 40069
#       total_uncompressed_size: 80039
#       type: 2
#     offset_index_length: null
#     offset_index_offset: null
#   - column_index_length: null
#     column_index_offset: null
#     crypto_metadata: null
#     encrypted_column_metadata: null
#     file_offset: 40073
#     file_path: null
#     meta_data:
#       bloom_filter_offset: null
#       codec: 1
#       data_page_offset: 40073
#       dictionary_page_offset: null
#       encoding_stats:
#       - count: 1
#         encoding: 0
#         page_type: 0
#       encodings:
#       - 0
#       index_page_offset: null
#       key_value_metadata: []
#       num_values: 10000
#       path_in_schema:
#       - Account ID
#       statistics:
#         distinct_count: null
#         max: null
#         max_value: null
#         min: null
#         min_value: null
#         null_count: 0
#       total_compressed_size: 24129
#       total_uncompressed_size: 130039
#       type: 6
#     offset_index_length: null
#     offset_index_offset: null
#   - column_index_length: null
#     column_index_offset: null
#     crypto_metadata: null
#     encrypted_column_metadata: null
#     file_offset: 64202
#     file_path: null
#     meta_data:
#       bloom_filter_offset: null
#       codec: 1
#       data_page_offset: 64202
#       dictionary_page_offset: null
#       encoding_stats:
#       - count: 1
#         encoding: 0
#         page_type: 0
#       encodings:
#       - 0
#       index_page_offset: null
#       key_value_metadata: []
#       num_values: 10000
#       path_in_schema:
#       - Transaction Amount
#       statistics:
#         distinct_count: null
#         max: b'fffff?\x9f@'
#         max_value: null
#         min: b'\xb8\x1e\x85\xebQ8$@'
#         min_value: null
#         null_count: 0
#       total_compressed_size: 48356
#       total_uncompressed_size: 80039
#       type: 5
#     offset_index_length: null
#     offset_index_offset: null
#   - column_index_length: null
#     column_index_offset: null
#     crypto_metadata: null
#     encrypted_column_metadata: null
#     file_offset: 112558
#     file_path: null
#     meta_data:
#       bloom_filter_offset: null
#       codec: 1
#       data_page_offset: 112558
#       dictionary_page_offset: null
#       encoding_stats:
#       - count: 1
#         encoding: 0
#         page_type: 0
#       encodings:
#       - 0
#       index_page_offset: null
#       key_value_metadata: []
#       num_values: 10000
#       path_in_schema:
#       - Transaction Type
#       statistics:
#         distinct_count: null
#         max: null
#         max_value: null
#         min: null
#         min_value: null
#         null_count: 0
#       total_compressed_size: 19913
#       total_uncompressed_size: 114637
#       type: 6
#     offset_index_length: null
#     offset_index_offset: null
#   - column_index_length: null
#     column_index_offset: null
#     crypto_metadata: null
#     encrypted_column_metadata: null
#     file_offset: 132471
#     file_path: null
#     meta_data:
#       bloom_filter_offset: null
#       codec: 1
#       data_page_offset: 132471
#       dictionary_page_offset: null
#       encoding_stats:
#       - count: 1
#         encoding: 0
#         page_type: 0
#       encodings:
#       - 0
#       index_page_offset: null
#       key_value_metadata: []
#       num_values: 10000
#       path_in_schema:
#       - Merchant/Counterparty
#       statistics:
#         distinct_count: null
#         max: null
#         max_value: null
#         min: null
#         min_value: null
#         null_count: 0
#       total_compressed_size: 24633
#       total_uncompressed_size: 135012
#       type: 6
#     offset_index_length: null
#     offset_index_offset: null
#   - column_index_length: null
#     column_index_offset: null
#     crypto_metadata: null
#     encrypted_column_metadata: null
#     file_offset: 157104
#     file_path: null
#     meta_data:
#       bloom_filter_offset: null
#       codec: 1
#       data_page_offset: 157104
#       dictionary_page_offset: null
#       encoding_stats:
#       - count: 1
#         encoding: 0
#         page_type: 0
#       encodings:
#       - 0
#       index_page_offset: null
#       key_value_metadata: []
#       num_values: 10000
#       path_in_schema:
#       - Location
#       statistics:
#         distinct_count: null
#         max: null
#         max_value: null
#         min: null
#         min_value: null
#         null_count: 0
#       total_compressed_size: 22950
#       total_uncompressed_size: 146568
#       type: 6
#     offset_index_length: null
#     offset_index_offset: null
#   - column_index_length: null
#     column_index_offset: null
#     crypto_metadata: null
#     encrypted_column_metadata: null
#     file_offset: 180054
#     file_path: null
#     meta_data:
#       bloom_filter_offset: null
#       codec: 1
#       data_page_offset: 180054
#       dictionary_page_offset: null
#       encoding_stats:
#       - count: 1
#         encoding: 0
#         page_type: 0
#       encodings:
#       - 0
#       index_page_offset: null
#       key_value_metadata: []
#       num_values: 10000
#       path_in_schema:
#       - Date and Time
#       statistics:
#         distinct_count: null
#         max: null
#         max_value: null
#         min: null
#         min_value: null
#         null_count: 0
#       total_compressed_size: 42096
#       total_uncompressed_size: 200039
#       type: 6
#     offset_index_length: null
#     offset_index_offset: null
#   file_offset: null
#   num_rows: 10000
#   ordinal: null
#   sorting_columns: null
#   total_byte_size: 886373
#   total_compressed_size: null
# schema:
# - converted_type: null
#   field_id: null
#   logicalType: null
#   name: schema
#   num_children: 7
#   precision: null
#   repetition_type: null
#   scale: null
#   type: null
#   type_length: null
# - converted_type: null
#   field_id: null
#   logicalType: null
#   name: Transaction ID
#   num_children: null
#   precision: null
#   repetition_type: 1
#   scale: null
#   type: 2
#   type_length: 64
# - converted_type: 0
#   field_id: null
#   logicalType: null
#   name: Account ID
#   num_children: null
#   precision: null
#   repetition_type: 1
#   scale: null
#   type: 6
#   type_length: null
# - converted_type: null
#   field_id: null
#   logicalType: null
#   name: Transaction Amount
#   num_children: null
#   precision: null
#   repetition_type: 1
#   scale: null
#   type: 5
#   type_length: 64
# - converted_type: 0
#   field_id: null
#   logicalType: null
#   name: Transaction Type
#   num_children: null
#   precision: null
#   repetition_type: 1
#   scale: null
#   type: 6
#   type_length: null
# - converted_type: 0
#   field_id: null
#   logicalType: null
#   name: Merchant/Counterparty
#   num_children: null
#   precision: null
#   repetition_type: 1
#   scale: null
#   type: 6
#   type_length: null
# - converted_type: 0
#   field_id: null
#   logicalType: null
#   name: Location
#   num_children: null
#   precision: null
#   repetition_type: 1
#   scale: null
#   type: 6
#   type_length: null
# - converted_type: 0
#   field_id: null
#   logicalType: null
#   name: Date and Time
#   num_children: null
#   precision: null
#   repetition_type: 1
#   scale: null
#   type: 6
#   type_length: null
# version: 1
